# %% [markdown]
# Import Libraries

# %%
import sys
import PIL

print("Python path:", sys.executable)
print("PIL path:", PIL.__file__)
# Out:
# Python path: /home/dhyan/Desktop/DL/venv/bin/python
# PIL path: /home/dhyan/Desktop/DL/venv/lib/python3.12/site-packages/PIL/__init__.py

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
tf.__version__
# Out:
# '2.21.0'

# %% [markdown]
# Image Transformation (Data Augmentation)

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory(
    'dataset/training_set',
    image_size=(64, 64),
    batch_size=32
)
# Out:
# Found 8000 files belonging to 2 classes.

# %%
test_dataset = tf.keras.utils.image_dataset_from_directory(
    'dataset/test_set',
    image_size=(64, 64),
    batch_size=32
)
# Out:
# Found 2000 files belonging to 2 classes.

# %% [markdown]
# Initialize CNN Object

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# Add Convolution Layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu',input_shape=[64,64,3]))

# %% [markdown]
# Pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %% [markdown]
# Add another convolution layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu',input_shape=[64,64,3]))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %% [markdown]
# Flatenning

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units=32,activation='relu'))

# %% [markdown]
# Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))

# %% [markdown]
# Compiling CNN

# %%
cnn.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
from PIL import Image
cnn.fit(x=train_dataset,validation_data=test_dataset,epochs=25)
# Out:
# Epoch 1/25
#   3/250 ━━━━━━━━━━━━━━━━━━━━ 18s 75ms/step - accuracy: 0.4722 - loss: 70.2361
# W0000 00:00:1774260422.022013    7495 cpu_allocator_impl.cc:82] Allocation of 28096128 exceeds 10% of free system memory.
# W0000 00:00:1774260422.022381    7498 cpu_allocator_impl.cc:82] Allocation of 28096128 exceeds 10% of free system memory.
# W0000 00:00:1774260422.098999    7490 cpu_allocator_impl.cc:82] Allocation of 28096128 exceeds 10% of free system memory.
# W0000 00:00:1774260422.098999    7496 cpu_allocator_impl.cc:82] Allocation of 28096128 exceeds 10% of free system memory.
# W0000 00:00:1774260422.172463    7498 cpu_allocator_impl.cc:82] Allocation of 28096128 exceeds 10% of free system memory.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 57ms/step - accuracy: 0.5415 - loss: 2.3540 - val_accuracy: 0.5770 - val_loss: 0.6783
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 52ms/step - accuracy: 0.6229 - loss: 0.6477 - val_accuracy: 0.5575 - val_loss: 0.7046
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 53ms/step - accuracy: 0.6827 - loss: 0.5772 - val_accuracy: 0.6035 - val_loss: 0.7580
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 61ms/step - accuracy: 0.7349 - loss: 0.5057 - val_accuracy: 0.6165 - val_loss: 0.7981
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 59ms/step - accuracy: 0.7896 - loss: 0.4319 - val_accuracy: 0.6160 - val_loss: 1.0062
# Epoch 6/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 53ms/step - accuracy: 0.8330 - loss: 0.3542 - val_accuracy: 0.6130 - val_loss: 1.1350
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 55ms/step - accuracy: 0.8686 - loss: 0.2890 - val_accuracy: 0.5895 - val_loss: 1.4051
# Epoch 8/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - accuracy: 0.8917 - loss: 0.2514 - val_accuracy: 0.6205 - val_loss: 1.3732
# Epoch 9/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 58ms/step - accuracy: 0.9103 - loss: 0.2230 - val_accuracy: 0.6085 - val_loss: 1.3426
# Epoch 10/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 52ms/step - accuracy: 0.9367 - loss: 0.1599 - val_accuracy: 0.6135 - val_loss: 1.6232
# Epoch 11/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 52ms/step - accuracy: 0.9346 - loss: 0.1570 - val_accuracy: 0.6060 - val_loss: 1.5853
# Epoch 12/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 55ms/step - accuracy: 0.9448 - loss: 0.1432 - val_accuracy: 0.6155 - val_loss: 1.7322
# Epoch 13/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 52ms/step - accuracy: 0.9414 - loss: 0.1471 - val_accuracy: 0.6170 - val_loss: 1.7407
# Epoch 14/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 53ms/step - accuracy: 0.9596 - loss: 0.1074 - val_accuracy: 0.6150 - val_loss: 1.8372
# Epoch 15/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 54ms/step - accuracy: 0.9628 - loss: 0.1053 - val_accuracy: 0.6135 - val_loss: 2.0326
# Epoch 16/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 53ms/step - accuracy: 0.9603 - loss: 0.1205 - val_accuracy: 0.6010 - val_loss: 2.4518
# Epoch 17/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9641 - loss: 0.1063 - val_accuracy: 0.6040 - val_loss: 2.2359
# Epoch 18/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - accuracy: 0.9699 - loss: 0.0947 - val_accuracy: 0.6110 - val_loss: 2.3185
# Epoch 19/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9701 - loss: 0.0831 - val_accuracy: 0.5950 - val_loss: 2.3728
# Epoch 20/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - accuracy: 0.9694 - loss: 0.0934 - val_accuracy: 0.6180 - val_loss: 2.6089
# Epoch 21/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - accuracy: 0.9775 - loss: 0.0755 - val_accuracy: 0.6120 - val_loss: 2.4973
# Epoch 22/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - accuracy: 0.9734 - loss: 0.0885 - val_accuracy: 0.6145 - val_loss: 2.7434
# Epoch 23/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9781 - loss: 0.0634 - val_accuracy: 0.6295 - val_loss: 2.9691
# Epoch 24/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - accuracy: 0.9620 - loss: 0.1236 - val_accuracy: 0.6110 - val_loss: 2.8926
# Epoch 25/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9766 - loss: 0.0657 - val_accuracy: 0.6250 - val_loss: 2.8698

# %%
loss, accuracy = cnn.evaluate(test_set)

print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 loss, accuracy = cnn.evaluate(test_set)
#       3 print("Test Loss:", loss)
#       4 print("Test Accuracy:", accuracy)
#
# NameError: name 'test_set' is not defined
